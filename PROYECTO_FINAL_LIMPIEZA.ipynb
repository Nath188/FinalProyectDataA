# %% [markdown]
# <a href="https://colab.research.google.com/github/Nath188/FinalProyectDataA/blob/main/PROYECTO_FINAL_LIMPIEZA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LIMPIEZA DE DATASET**

# %%
import pandas as pd
import numpy as np
import os
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b772c90-c5b1-457a-b4ae-5198c375abf2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b772c90-c5b1-457a-b4ae-5198c375abf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel(io.BytesIO(uploaded["anexos_edu_2019 (2).xls" ]))
df
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                  GRAN ENCUESTA INTEGRADA DE HOGARES
# 2                                                 NaN
# 3                          Fuerza Laboral y Educación
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  1.
# 7                                                  2.
# 8                                                 NaN
# 9                                                  3.
# 10                                                NaN
# 11                                                 4.
# 12                                                NaN
# 13                                                 5.
# 14                                                NaN
# 15                                                 6.
# ...

# %%
df.dropna()
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 6          1.                                 Ficha metodológica
# 7          2.  Población económicamente activa que asiste o n...
# 9          3.  Población ocupada, desocupada e inactiva según...
# 11         4.  Población ocupada según último título obtenido...
# 13         5.  Población ocupada según último título obtenido...
# 15         6.  Población ocupada según último título educativ...
# 18         7.  Población ocupada, desocupada e inactiva según...
# 20         8.  Población ocupada según nivel educativo alcanz...
# 22         9.  Población ocupada según nivel educativo alcanz...
# 24        10.  Población ocupada según nivel educativo alcanz...
# 26        11.                                  Errores relativos

# %%
df_titulo_obtenido = pd.read_excel("anexos_edu_2019 (2).xls", sheet_name='título Obtenido', skiprows=3)
df_titulo_obtenido['SHEET'] = 'título Obtenido'

# %%
df_titulo_oficio = pd.read_excel("anexos_edu_2019 (2).xls", sheet_name='título oficio', skiprows=3)
df_titulo_oficio['SHEET'] = 'título oficio'

# %%
df_titulo_posicion = pd.read_excel("anexos_edu_2019 (2).xls", sheet_name='título posición', skiprows=3)
df_titulo_posicion['SHEET'] = 'título posición'

# %%
df_titulo_ingreso = pd.read_excel("anexos_edu_2019 (2).xls", sheet_name='título ingresos', skiprows=3)
df_titulo_ingreso['SHEET'] = 'título ingresos'

# %%
df_titulos_2019 = pd.concat ([df_titulo_obtenido, df_titulo_oficio, df_titulo_posicion, df_titulo_ingreso])
df_titulos_2019.head(5)
# Out:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  Población ocupada, desocupada e inactiva según...        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2                                              Total        NaN         NaN
# 3                                           Concepto        Año         NaN
# 4                                                NaN       2010      2011.0
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4      2012.0      2013.0      2014.0      2015.0      2016.0      2017.0
#
#    Unnamed: 9  Unnamed: 10            SHEET
# ...

# %%
df_titulos_2019 = df_titulos_2019.dropna(how='any')
df_titulos_2019
# Out:
#                               Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 5                                    PET   34706.228   35247.947
# 6                               Ocupados   19213.322   20019.511
# 7                            Desocupados    2563.985    2426.095
# 8                              Inactivos   12928.921   12802.341
# 10                              Ocupados  19213.3225   20019.511
# ..                                   ...         ...         ...
# 35                           No informa*      18.475      19.442
# 36                      De 0 a 0.5 SMMLV      65.116      74.430
# 37  Más de 0.5 y menor o igual a 1 SMMLV      97.403      84.436
# 38  Más de 1 y menor o igual a 1.5 SMMLV     120.653     158.852
# 39                     Mayor a 1.5 SMMLV     1623.76    1654.673
#
#       Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 5   35781.056000   36306.639   36826.518   37342.466   37851.363   38354.931
# ...

# %%
len(df_titulos_2019)
# Out:
# 181

# %%
df_titulos_2019.dtypes
# Out:
# Unnamed: 0      object
# Unnamed: 1      object
# Unnamed: 2     float64
# Unnamed: 3     float64
# Unnamed: 4     float64
# Unnamed: 5     float64
# Unnamed: 6     float64
# Unnamed: 7     float64
# Unnamed: 8     float64
# Unnamed: 9     float64
# Unnamed: 10    float64
# SHEET           object
# dtype: object

# %%
df_titulos_2019.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'SHEET'],
#       dtype='object')

# %%
df_titulos_2019.columns = ['concepto','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','titulo clase']
df_titulos_2019
# Out:
#                                 concepto        2010       2011          2012  \
# 5                                    PET   34706.228  35247.947  35781.056000
# 6                               Ocupados   19213.322  20019.511  20696.418000
# 7                            Desocupados    2563.985   2426.095   2394.227000
# 8                              Inactivos   12928.921  12802.341  12690.412000
# 10                              Ocupados  19213.3225  20019.511  20696.417417
# ..                                   ...         ...        ...           ...
# 35                           No informa*      18.475     19.442     20.053000
# 36                      De 0 a 0.5 SMMLV      65.116     74.430     64.990000
# 37  Más de 0.5 y menor o igual a 1 SMMLV      97.403     84.436     89.389000
# 38  Más de 1 y menor o igual a 1.5 SMMLV     120.653    158.852    159.832000
# 39                     Mayor a 1.5 SMMLV     1623.76   1654.673   1668.841000
#
# ...

# %%
df_titulos_2019 = df_titulos_2019.dropna(how='any')
df_titulos_2019
# Out:
#                                 concepto        2010       2011          2012  \
# 5                                    PET   34706.228  35247.947  35781.056000
# 6                               Ocupados   19213.322  20019.511  20696.418000
# 7                            Desocupados    2563.985   2426.095   2394.227000
# 8                              Inactivos   12928.921  12802.341  12690.412000
# 10                              Ocupados  19213.3225  20019.511  20696.417417
# ..                                   ...         ...        ...           ...
# 35                           No informa*      18.475     19.442     20.053000
# 36                      De 0 a 0.5 SMMLV      65.116     74.430     64.990000
# 37  Más de 0.5 y menor o igual a 1 SMMLV      97.403     84.436     89.389000
# 38  Más de 1 y menor o igual a 1.5 SMMLV     120.653    158.852    159.832000
# 39                     Mayor a 1.5 SMMLV     1623.76   1654.673   1668.841000
#
# ...

# %% [markdown]
# # **EXPLORACION DE DATOS**

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df_titulos_2019
# Out:
#                                 concepto        2010       2011          2012  \
# 5                                    PET   34706.228  35247.947  35781.056000
# 6                               Ocupados   19213.322  20019.511  20696.418000
# 7                            Desocupados    2563.985   2426.095   2394.227000
# 8                              Inactivos   12928.921  12802.341  12690.412000
# 10                              Ocupados  19213.3225  20019.511  20696.417417
# ..                                   ...         ...        ...           ...
# 35                           No informa*      18.475     19.442     20.053000
# 36                      De 0 a 0.5 SMMLV      65.116     74.430     64.990000
# 37  Más de 0.5 y menor o igual a 1 SMMLV      97.403     84.436     89.389000
# 38  Más de 1 y menor o igual a 1.5 SMMLV     120.653    158.852    159.832000
# 39                     Mayor a 1.5 SMMLV     1623.76   1654.673   1668.841000
#
# ...

# %% [markdown]
# # **Visión general del Dataset **

# %%
df_titulos_2019.columns
# Out:
# Index(['concepto', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', 'titulo clase'],
#       dtype='object')

# %%
df_titulos_2019.dtypes
# Out:
# concepto         object
# 2010             object
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# titulo clase     object
# dtype: object

# %%
df_titulos_2019.describe()
# Out:
#                2011          2012          2013          2014          2015  \
# count    181.000000    181.000000    181.000000    181.000000    181.000000
# mean    2885.180729   2953.621359   3000.173635   3053.326077   3110.199044
# std     5056.903507   5159.717780   5225.575471   5310.006949   5404.254442
# min        0.572000      0.201000      0.289000      0.578000      0.437000
# 25%      153.866000    171.960000    177.780000    186.578000    192.201000
# 50%      809.028000    855.187000    904.022000    859.342000    873.840000
# 75%     3222.732000   3270.347000   3118.663000   3171.683000   3243.399000
# max    35247.947000  35781.056000  36306.639000  36826.518000  37342.466000
#
#                2016          2017          2018          2019
# count    181.000000    181.000000    181.000000    181.000000
# mean    3141.903856   3179.173547   3206.490166   3217.075878
# std     5450.884763   5505.199186   5544.020651   5553.757727
# ...

# %%
df_titulos_2019 = df_titulos_2019[['concepto', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019', 'titulo clase']]

# %% [markdown]
# # Análisis unidimensional de las variables

# %%
df_titulos_2019['titulo clase'].value_counts()
# Out:
# título Obtenido    66
# título oficio      45
# título posición    40
# título ingresos    30
# Name: titulo clase, dtype: int64

# %%
df_titulos_2019['2015'].value_counts()
# Out:
# 22017.192    5
# 10580.536    4
# 6721.044     4
# 2386.506     4
# 2329.105     3
#             ..
# 2302.028     1
# 563.936      1
# 1919.654     1
# 3801.319     1
# 1928.380     1
# Name: 2015, Length: 154, dtype: int64

# %%
list(df_titulos_2019['2019'].value_counts(normalize=True))
# Out:
# [0.027624309392265192,
#  0.022099447513812154,
#  0.022099447513812154,
#  0.022099447513812154,
#  0.016574585635359115,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.011049723756906077,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
#  0.0055248618784530384,
# ...

# %%
df_titulos_2019['titulo clase'].hist()
# Out:
# <Axes: >

# %%
df_titulos_2019 [df_titulos_2019['2019'] > df_titulos_2019['2019'].quantile(0.95)]['2019'].hist(bins=15)
# Out:
# <Axes: >

# %%
df_titulos_2019 [df_titulos_2019['2019'] > df_titulos_2019['2019'].quantile(0.95)].head(10)
# Out:
#           concepto        2010       2011          2012       2013       2014  \
# 5              PET   34706.228  35247.947  35781.056000  36306.639  36826.518
# 6         Ocupados   19213.322  20019.511  20696.418000  21048.193  21503.323
# 8        Inactivos   12928.921  12802.341  12690.412000  13015.082  13172.036
# 10        Ocupados  19213.3225  20019.511  20696.417417  21048.193  21503.323
# 34             PET   16953.107  17220.742  17483.876000  17743.344  18000.172
# 63             PET   17753.121  18027.205  18297.180000  18563.295  18826.346
# 5   Total Ocupados   19213.322  20019.511  20696.418000  21048.193  21503.323
# 5   Total Ocupados   19213.322  20019.511  20696.418000  21048.193  21503.323
# 5   Total Ocupados   19213.322  20019.511  20696.418000  21048.193  21503.323
#
#          2015       2016       2017       2018       2019     titulo clase
# 5   37342.466  37851.363  38354.931  38861.109  39355.422  título Obtenido
# ...

# %% [markdown]
# # Análisis multidimensional de las variables

# %%
sum_titulo_categoria = df_titulos_2019.groupby('concepto').sum()['2019']
sum_titulo_categoria
# Out:
# concepto
# Bachiller                                  46711.525
# Comerciantes y Vendedores                   7499.612
# Cuenta propia                              18900.572
# De 0 a 0.5 SMMLV                           11051.648
# Desocupadas                                 2910.000
# Desocupados                                 7549.835
# Directores y funcionarios públicos           958.472
# Empleado doméstico                          1375.432
# Inactivas                                  18858.392
# Inactivos                                  38954.340
# Mayor a 1.5 SMMLV                          10761.176
# Más de 0.5 y menor o igual a 1 SMMLV        9354.829
# Más de 1 y menor o igual a 1.5 SMMLV       11737.824
# Ninguno                                    69259.600
# No informa                                   379.884
# No informa*                                 1669.084
# Obrero o empleado del gobierno              1657.856
# ...

# %%
sum_titulo_categoria.reset_index().sort_values(by='concepto', ascending = False).iloc[0:10].plot(kind='bar', x='concepto', y ='2019' )
# Out:
# <Axes: xlabel='concepto'>

# %%
mean_importe_sheet = df_titulos_2019.groupby('titulo clase').mean ()['2019']
mean_importe_sheet.reset_index().sort_values(by='2019', ascending = False).iloc[0:10].plot(kind='bar', x='titulo clase', y ='2019')
# Out:
# <Axes: xlabel='titulo clase'>

# %%
mean_importe_sheet.reset_index().sort_values(by='2019', ascending = False).iloc[0:10]
# Out:
#       titulo clase         2019
# 0  título Obtenido  4770.354152
# 1  título ingresos  2971.637367
# 3  título posición  2228.728025
# 2    título oficio  1981.091511

# %%
df_titulos_2019.groupby(['concepto','titulo clase','2019']).sum()
# Out:
#                                                           2011      2012  \
# concepto                    titulo clase    2019
# Bachiller                   título Obtenido 489.468    426.089   404.321
#                                             633.194    567.736   550.028
#                                             933.500    636.430   611.578
#                                             1122.662   993.825   954.348
#                                             2339.218  1616.825  1607.649
# ...                                                        ...       ...
# Universitario               título Obtenido 1015.086   722.825   726.350
#                                             1923.399  1402.467  1400.560
# Universitario y/o postgrado título ingresos 2805.213  1991.832  2003.105
#                             título oficio   2805.213  1991.832  2003.105
#                             título posición 2805.213  1991.832  2003.105
#
# ...

# %%
df_tt_class= df_titulos_2019.groupby(['concepto','titulo clase',]).sum()['2019'].sort_values().unstack('titulo clase')
df_tt_class
# Out:
# titulo clase                             título Obtenido  título ingresos  \
# concepto
# Bachiller                                      23959.066         7584.153
# Comerciantes y Vendedores                            NaN              NaN
# Cuenta propia                                        NaN              NaN
# De 0 a 0.5 SMMLV                                     NaN        11051.648
# Desocupadas                                     2910.000              NaN
# Desocupados                                     7549.835              NaN
# Directores y funcionarios públicos                   NaN              NaN
# Empleado doméstico                                   NaN              NaN
# Inactivas                                      18858.392              NaN
# Inactivos                                      38954.340              NaN
# Mayor a 1.5 SMMLV                                    NaN        10761.176
# ...

# %%
top_titulo = df_titulos_2019.groupby ('concepto')['2019'].sum().sort_values(ascending=False).index[0:10]
top_titulo
# Out:
# Index(['PET', 'Ocupados', 'Ninguno', 'Total Ocupados', 'Bachiller',
#        'Inactivos', 'Obrero o empleado particular*', 'Cuenta propia',
#        'Inactivas', 'Ocupadas'],
#       dtype='object', name='concepto')

# %%
df_tt_class.loc[top_titulo]
# Out:
# titulo clase                   título Obtenido  título ingresos  \
# concepto
# PET                                  78710.844              NaN
# Ocupados                             70701.280              NaN
# Ninguno                              40950.139         9436.487
# Total Ocupados                             NaN        22287.280
# Bachiller                            23959.066         7584.153
# Inactivos                            38954.340              NaN
# Obrero o empleado particular*              NaN              NaN
# Cuenta propia                              NaN              NaN
# Inactivas                            18858.392              NaN
# Ocupadas                             18447.840              NaN
#
# titulo clase                   título oficio  título posición
# concepto
# PET                                      NaN              NaN
# Ocupados                                 NaN              NaN
# ...

# %%
df_tt_class.loc[top_titulo].plot.bar(stacked=True)
# Out:
# <Axes: xlabel='concepto'>

# %% [markdown]
# # Análisis de texto

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('spanish'))
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 
# ...

# %%
textos_encuestas=''
for row in df_titulos_2019['concepto']:
  textos_encuestas=textos_encuestas +''+row

# %%
stopwords_list=stopwords.words('spanish')+ ['mile', ' pea', 'dane', 'etc']

# %%
textos_encuestas= ' '.join([x for x in textos_encuestas.strip().lower().split(' ') if x not in stopwords_list and len(x)>4])

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import socket

# %%
wc = WordCloud(background_color='white')
wc.generate(textos_encuestas)

plt.axis("off")
plt.imshow(wc, interpolation ='bilinear')
plt.show()

# %%
# %matplotlib inline
import pandas as pd

# %%
df_titulos_2019
# Out:
#                                 concepto        2010       2011          2012  \
# 5                                    PET   34706.228  35247.947  35781.056000
# 6                               Ocupados   19213.322  20019.511  20696.418000
# 7                            Desocupados    2563.985   2426.095   2394.227000
# 8                              Inactivos   12928.921  12802.341  12690.412000
# 10                              Ocupados  19213.3225  20019.511  20696.417417
# ..                                   ...         ...        ...           ...
# 35                           No informa*      18.475     19.442     20.053000
# 36                      De 0 a 0.5 SMMLV      65.116     74.430     64.990000
# 37  Más de 0.5 y menor o igual a 1 SMMLV      97.403     84.436     89.389000
# 38  Más de 1 y menor o igual a 1.5 SMMLV     120.653    158.852    159.832000
# 39                     Mayor a 1.5 SMMLV     1623.76   1654.673   1668.841000
#
# ...

# %%
df_titulos_2019.dtypes
# Out:
# concepto         object
# 2010             object
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# titulo clase     object
# dtype: object

# %% [markdown]
# ##EXPANCION DE DATOS QUE TENEMOS, EJEMPLO FECHA

# %% [markdown]
# ## PROYECTAMOS UNAS VARIABLES CON OTRAS

# %%
concepto_xa = df_titulos_2019 ['titulo clase'].value_counts().to_dict()

# %%
list(concepto_xa.keys())[0:4]
# Out:
# ['título Obtenido', 'título oficio', 'título posición', 'título ingresos']

# %%
df_titulos_2019['concepto_xa'] = df_titulos_2019['titulo clase'].apply(lambda x: concepto_xa[x])

# %%
sheet_mean_titulos = df_titulos_2019.groupby('titulo clase')['2019'].mean()
sheet_mean_titulos
# Out:
# titulo clase
# título Obtenido    4770.354152
# título ingresos    2971.637367
# título oficio      1981.091511
# título posición    2228.728025
# Name: 2019, dtype: float64

# %%
sheet_mean_titulos.to_dict()
# Out:
# {'título Obtenido': 4770.354151515152,
#  'título ingresos': 2971.637366666667,
#  'título oficio': 1981.0915111111112,
#  'título posición': 2228.728025}

# %%
df_titulos_2019['concepto'] = df_titulos_2019['titulo clase'].apply(lambda x: sheet_mean_titulos[x])

# %% [markdown]
# ## TRAEMOS INFORMACION EXTERNA ENRIQUECER LOS DATOS UTILIZANDO UN TOOL DE PGINAS DE LINKED IN

# %%
pd.DataFrame(df_titulos_2019['titulo clase'].unique()).to_csv('anexos_edu_2019 (2).xls', index=None)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33514733-612f-4a9a-a385-da0a3abafbf1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33514733-612f-4a9a-a385-da0a3abafbf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bdlatam=pd.read_excel(io.BytesIO(uploaded["banco de desarrollo .xlsx" ]))
bdlatam
# Out:
#                Data Source Indicadores del desarrollo mundial  \
# 0        Last Updated Date                2023-03-01 00:00:00
# 1                      NaN                                NaN
# 2             Country Name                       Country Code
# 3                 Colombia                                COL
# 4                 Colombia                                COL
# ...                    ...                                ...
# 2882  Ingreso mediano alto                                UMC
# 2883  Ingreso mediano alto                                UMC
# 2884  Ingreso mediano alto                                UMC
# 2885  Ingreso mediano alto                                UMC
# 2886  Ingreso mediano alto                                UMC
#
#                                              Unnamed: 2    Unnamed: 3  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# ...

# %%
bdlatam.dropna()
# Out:
#                Data Source Indicadores del desarrollo mundial  \
# 2             Country Name                       Country Code
# 3                 Colombia                                COL
# 4                 Colombia                                COL
# 5                 Colombia                                COL
# 9                 Colombia                                COL
# ...                    ...                                ...
# 2876  Ingreso mediano alto                                UMC
# 2877  Ingreso mediano alto                                UMC
# 2878  Ingreso mediano alto                                UMC
# 2879  Ingreso mediano alto                                UMC
# 2884  Ingreso mediano alto                                UMC
#
#                                              Unnamed: 2    Unnamed: 3  \
# 2                                        Indicator Name  2.010000e+03
# 3     Internally displaced persons, total displaced ...  5.196000e+06
# ...

# %%
bdlatam.columns
# Out:
# Index(['Data Source', 'Indicadores del desarrollo mundial', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
bdlatam.columns = ['Data Source', 'Indicadores del desarrollo mundial','item','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']
bdlatam
# Out:
#                Data Source Indicadores del desarrollo mundial  \
# 0        Last Updated Date                2023-03-01 00:00:00
# 1                      NaN                                NaN
# 2             Country Name                       Country Code
# 3                 Colombia                                COL
# 4                 Colombia                                COL
# ...                    ...                                ...
# 2882  Ingreso mediano alto                                UMC
# 2883  Ingreso mediano alto                                UMC
# 2884  Ingreso mediano alto                                UMC
# 2885  Ingreso mediano alto                                UMC
# 2886  Ingreso mediano alto                                UMC
#
#                                                    item          2010  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# ...

# %%
has_site={}
for i, ele in  bdlatam.fillna(True).iterrows():
  has_site[ele['2019']] = True if ele[0] == True else False

# %%
df_titulos_2019['has_bdlatam']= df_titulos_2019['2019'].apply(lambda x: has_site)

# %%
has_site
# Out:
# {True: False,
#  2019.0: False,
#  5576000.0: False,
#  54.193395622496574: False,
#  10485253589.9064: False,
#  39485080766.0: False,
#  0.3385614677914269: False,
#  17.038426323273637: False,
#  1.045285574705785: False,
#  54.694885645800504: False,
#  222.8863118: False,
#  20.810922912461077: False,
#  19.692356075169695: False,
#  2.5290482225773734: False,
#  23.78173728585078: False,
#  0.3768135682362071: False,
#  9.9115098566: False,
#  89.3147020052: False,
#  10.17: False,
#  99.92: False,
#  6.03: False,
#  99.98: False,
#  4.57: False,
#  100.0: False,
#  5658000000.0: False,
#  1102000000.0: False,
#  4531000.0: False,
#  2.233509463086878: False,
#  50.6264579603895: False,
#  43.951318361373545: False,
#  1.2870843289728: False,
#  8.20401926925632: False,
#  8.99266377810026: False,
#  4.00050630968162: False,
#  5.72655580558951: False,
#  6.56430744353927: False,
#  8.25365089999916: False,
#  8.99145218018861: False,
#  69.5348811493916: False,
# ...
